# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 632

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={weather_api_key}&units={units}&q="

lat = []
lng = []
temp = []
humidity = []
wind_speed = []
cloudiness = []
country = []
date = []
new_cities = []

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lng.append((response['coord']['lon']))
        temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        new_cities.append(city)
        print(f"Processing {city} found!.")
    except:
        print(f'{city} result does not exist')
        pass
# Out:
# Processing castro found!.
# Processing butaritari found!.
# Processing ilhabela found!.
# Processing sitka found!.
# Processing faanui found!.
# Processing norsup found!.
# Processing albany found!.
# Processing mar del plata found!.
# Processing port lincoln found!.
# Processing dikson found!.
# Processing nome found!.
# Processing norman wells found!.
# Processing candido mendes found!.
# Processing tuktoyaktuk found!.
# Processing ribeira grande found!.
# Processing east london found!.
# Processing hermanus found!.
# Processing kaitangata found!.
# Processing tessalit found!.
# Processing pevek found!.
# Processing vila franca do campo found!.
# Processing tessaoua found!.
# Processing constitucion found!.
# Processing hithadhoo found!.
# Processing sexsmith found!.
# Processing hobyo found!.
# Processing punta arenas found!.
# Processing hobart found!.
# Processing kodiak found!.
# Processing seydi found!.
# dinsor result does not exist
# Processing chokurdakh found!.
# Processing arman found!.
# Processing ordzhonikidze found!.
# Processing bethel found!.
# Processing mataura found!.
# dolbeau result does not exist
# taolanaro result does not exist
# Processing jamestown found!.
# Processing miri found!.
# Processing segou found!.
# mrirt result does not exist
# Processing verkhniy baskunchak found!.
# Processing hilo found!.
# Processing torbay found!.
# Processing mahebourg found!.
# Processing voloka found!.
# Processing pervomayskoye found!.
# belushya guba result does not exist
# kawana waters result does not exist
# Processing myaundzha found!.
# Processing nikolskoye found!.
# Processing qui nhon found!.
# Processing avarua found!.
# Processing bambous virieux found!.
# Processing seoul found!.
# Processing batemans bay found!.
# Processing carnarvon found!.
# Processing sambava found!.
# Processing rona de sus found!.
# Processing anaconda found!.
# Processing port alfred found!.
# Processing sao joao da barra found!.
# Processing ushuaia found!.
# mentok result does not exist
# Processing qaanaaq found!.
# Processing cape town found!.
# mys shmidta result does not exist
# Processing port elizabeth found!.
# Processing adrar found!.
# Processing yellowknife found!.
# Processing ormara found!.
# Processing vardo found!.
# Processing buala found!.
# Processing bathsheba found!.
# Processing asau found!.
# Processing esperance found!.
# Processing yeppoon found!.
# Processing busselton found!.
# Processing zlotoryja found!.
# Processing lata found!.
# Processing toro found!.
# Processing bikaner found!.
# Processing manggar found!.
# Processing sabae found!.
# Processing cherskiy found!.
# Processing salalah found!.
# Processing ancud found!.
# Processing lasa found!.
# Processing matara found!.
# Processing pundaguitan found!.
# Processing atuona found!.
# Processing lompoc found!.
# Processing mehamn found!.
# Processing northam found!.
# Processing betioky found!.
# Processing morondava found!.
# Processing biak found!.
# Processing kahului found!.
# Processing tucuman found!.
# Processing alofi found!.
# Processing fairbanks found!.
# Processing sao miguel do araguaia found!.
# Processing palmer found!.
# Processing palmdale found!.
# Processing itoman found!.
# Processing pangkalanbuun found!.
# Processing padang found!.
# Processing upernavik found!.
# Processing kapaa found!.
# Processing areosa found!.
# Processing ukiah found!.
# Processing dongsheng found!.
# Processing aksarka found!.
# nizhneyansk result does not exist
# Processing newport found!.
# Processing rawdon found!.
# Processing nanortalik found!.
# Processing sorland found!.
# Processing mount gambier found!.
# Processing emerald found!.
# Processing rikitea found!.
# bargal result does not exist
# Processing aykhal found!.
# Processing mareeba found!.
# Processing cidreira found!.
# barentsburg result does not exist
# Processing dutlwe found!.
# Processing vaini found!.
# lolua result does not exist
# Processing dingle found!.
# Processing ahmadpur sial found!.
# Processing redlands found!.
# Processing thompson found!.
# Processing mount isa found!.
# Processing gurupa found!.
# Processing puerto ayora found!.
# Processing oda found!.
# Processing airai found!.
# Processing marsa matruh found!.
# Processing filingue found!.
# fevralsk result does not exist
# Processing katsuura found!.
# Processing xichang found!.
# Processing meulaboh found!.
# Processing keflavik found!.
# Processing lagoa found!.
# Processing volchikha found!.
# Processing alpine found!.
# Processing tasiilaq found!.
# Processing urusha found!.
# Processing pasighat found!.
# Processing sao paulo de olivenca found!.
# Processing ust-omchug found!.
# Processing sakaiminato found!.
# Processing isangel found!.
# Processing sao gabriel da cachoeira found!.
# Processing broken hill found!.
# Processing uyemskiy found!.
# Processing skovorodino found!.
# tapaua result does not exist
# Processing victoria found!.
# Processing kavaratti found!.
# Processing narsaq found!.
# Processing mayo found!.
# Processing gornopravdinsk found!.
# Processing gao found!.
# Processing panzhihua found!.
# Processing barra found!.
# Processing bud found!.
# Processing midland found!.
# Processing barrow found!.
# Processing tual found!.
# Processing turukhansk found!.
# Processing terrell found!.
# Processing longyearbyen found!.
# Processing vestmanna found!.
# Processing mandalgovi found!.
# Processing soyo found!.
# Processing berlevag found!.
# tsihombe result does not exist
# Processing sola found!.
# Processing tateyama found!.
# Processing mercedes found!.
# Processing mankera found!.
# Processing saint george found!.
# Processing lorengau found!.
# Processing georgetown found!.
# Processing puro found!.
# illoqqortoormiut result does not exist
# Processing hasaki found!.
# Processing saldanha found!.
# Processing tevaitoa found!.
# Processing shimoda found!.
# Processing bluff found!.
# Processing saskylakh found!.
# Processing bonthe found!.
# Processing rawson found!.
# Processing tura found!.
# Processing clermont found!.
# Processing camana found!.
# Processing kalmunai found!.
# Processing santarem found!.
# Processing viedma found!.
# Processing senanga found!.
# Processing belyy yar found!.
# Processing alta floresta found!.
# Processing kihei found!.
# Processing pocao de pedras found!.
# Processing poum found!.
# Processing villa carlos paz found!.
# Processing sooke found!.
# Processing vung tau found!.
# Processing nambucca heads found!.
# Processing ketchikan found!.
# Processing bonavista found!.
# Processing engels found!.
# tubruq result does not exist
# Processing hibbing found!.
# Processing saint-philippe found!.
# Processing arraial do cabo found!.
# Processing maraa found!.
# grand river south east result does not exist
# Processing necochea found!.
# Processing mehriz found!.
# Processing waipawa found!.
# Processing majene found!.
# Processing ust-ilimsk found!.
# Processing ilulissat found!.
# Processing geraldton found!.
# Processing zhigansk found!.
# Processing san martin found!.
# Processing diglur found!.
# Processing banepa found!.
# tumannyy result does not exist
# Processing lichinga found!.
# Processing antalaha found!.
# Processing cairns found!.
# Processing muscat found!.
# Processing belaya gora found!.
# Processing kruisfontein found!.
# Processing trairi found!.
# Processing chanthaburi found!.
# Processing yerbogachen found!.
# Processing kananga found!.
# Processing dryden found!.
# Processing finschhafen found!.
# Processing hadejia found!.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_direct = {
    "City": new_cities,
    "Latitude": lat,
    "Longitude": lng,
    "Max Temperature": temp,
    "Humidity": humidity,
    "Wind Speed": wind_speed,
    "Cloudiness": cloudiness,
    "Country": country,
    "Data Receiving Time (GMT)": date}
weather_info = pd.DataFrame(weather_direct)
weather_info
# Out:
#             City  Latitude  Longitude  Max Temperature  Humidity  Wind Speed  \
# 0         castro    -24.79     -50.01            64.11        52        1.99
# 1     butaritari      3.07     172.79            81.12        71        3.49
# 2       ilhabela    -23.78     -45.36            73.69        79        3.58
# 3          sitka     57.05    -135.33            46.54        67        4.59
# 4         faanui    -16.48    -151.75            79.77        81       17.65
# ..           ...       ...        ...              ...       ...         ...
# 576  yerbogachen     61.28     108.01            17.49        87       13.24
# 577      kananga     -5.90      22.42            69.22        98        1.74
# 578       dryden     49.78     -92.75            26.38        91        8.52
# 579  finschhafen     -6.60     147.87            84.52        68        9.62
# 580      hadejia     12.45      10.04            80.33        19        9.53
#
#      Cloudiness Country  Data Receiving Time (GMT)
# 0             0      BR                 1603926808
# 1           100      KI                 1603926692
# 2             0      BR                 1603927114
# 3            34      US                 1603926701
# 4            18      PF                 1603926719
# ..          ...     ...                        ...
# 576         100      RU                 1603926831
# 577          96      CD                 1603927174
# 578          96      CA                 1603927174
# 579          89      PG                 1603927174
# 580           0      NG                 1603927174
#
# [581 rows x 9 columns]

# %%
weather_info.describe()
# Out:
#          Latitude   Longitude  Max Temperature    Humidity  Wind Speed  \
# count  581.000000  581.000000       581.000000  581.000000  581.000000
# mean    21.179811   22.509363        57.913821   73.790017    7.192547
# std     32.909883   90.726346        22.169267   20.757732    5.302349
# min    -54.800000 -179.170000        -9.650000    7.000000    0.290000
# 25%     -5.200000  -58.800000        43.750000   67.000000    3.220000
# 50%     26.930000   27.190000        63.660000   80.000000    5.860000
# 75%     49.220000  103.530000        77.180000   88.000000    9.620000
# max     78.220000  178.420000        90.570000  100.000000   38.250000
#
#        Cloudiness  Data Receiving Time (GMT)
# count  581.000000               5.810000e+02
# mean    54.979346               1.603927e+09
# std     40.129526               2.056135e+02
# min      0.000000               1.603926e+09
# 25%      8.000000               1.603927e+09
# 50%     62.000000               1.603927e+09
# 75%     96.000000               1.603927e+09
# max    100.000000               1.603927e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidity_over100 = weather_info.loc[(weather_info['Humidity'] > 100)]
humidity_over100
# Out:
# Empty DataFrame
# Columns: [City, Latitude, Longitude, Max Temperature, Humidity, Wind Speed, Cloudiness, Country, Data Receiving Time (GMT)]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
latitude = weather_info['Latitude']
plt.scatter(latitude,weather_info['Max Temperature'],marker="o",facecolors="violet", edgecolors="black",alpha=0.9)
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.title('City Latitude vs. Max Temperature 10/28/2020')
plt.tight_layout()
plt.grid()
plt.show()
#Generally temperatures rise when approaching the equator as shown here.
#This is shown buy the general curve on this graph.
#Which shows as you get further from 0(Closest point to the equator) the higher the temperature gets

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(latitude,weather_info['Humidity'],marker="o",facecolors="violet", edgecolors="black",alpha=0.9)
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.title('City Latitude vs. Humidity 10/28/2020')
plt.tight_layout()
plt.grid()
plt.show()
#There does not appear to be any significant relationships between Latitude and Humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(latitude,weather_info['Cloudiness'],marker="o",facecolors="violet", edgecolors="black",alpha=0.9)
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.title('City Latitude vs. Cloudiness 10/28/2020')
plt.tight_layout()
plt.grid()
plt.show()
#There also doesn't appear to be much relationship here as well

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(latitude,weather_info['Wind Speed'],marker="o",facecolors="violet", edgecolors="black",alpha=0.9)
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.title('City Latitude vs. Wind Speed(Mph) 10/28/2020')
plt.tight_layout()
plt.grid()
plt.show()
#Again, visually there is no relationship
#But it is interesting to see the amount of focus for windspeeds under 15 mph

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
northern_hem = weather_info.loc[(weather_info['Latitude'] > 0)]
northern_lat = northern_hem['Latitude']

plt.scatter(northern_lat,northern_hem['Max Temperature'],marker="o", facecolors="violet", edgecolors ="black")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere Max Temperature vs. City Latitude 10/28/2020')
slope, intercept, r, p, std_err = linregress(northern_lat,northern_hem['Max Temperature'])
fit = slope * northern_lat + intercept
plt.plot(northern_lat,fit,color='black')
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.annotate(line_eq,(50,85),fontsize=12,color="black")
plt.show()
print(f'The r-value is {r}')
# Out:
# The r-value is -0.8676535822158702

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
southern_hem = weather_info.loc[(weather_info['Latitude'] < 0)]
southern_lat = southern_hem['Latitude']

plt.scatter(southern_lat,southern_hem['Max Temperature'],marker="o", facecolors="violet", edgecolors ="black")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere City Latitude vs. Max Temperature 10/28/2020')

slope, intercept, r, p, std_err = linregress(southern_lat,southern_hem['Max Temperature'])
fit = slope * southern_lat + intercept
plt.plot(southern_lat,fit,color='black')
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.annotate(line_eq,(-50,85),fontsize=12,color="black")
plt.show()
print(f'The r-value is {r}')
# Out:
# The r-value is 0.7377470135573414

# %%
#Both of the Hemisphere plots show a relatively strong correlation.
#Expectedly they both showing the closer you reach the equator(0) the higher temperature there is

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(northern_lat,northern_hem['Humidity'],marker="o", facecolors="violet", edgecolors ="black")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere City Humidity vs. Latitude 10/28/2020')

slope, intercept, r, p, std_err = linregress(northern_lat,northern_hem['Humidity'])
fit = slope * northern_lat + intercept
plt.plot(northern_lat,fit,color='black')
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.annotate(line_eq,(45,10),fontsize=12,color="black")
plt.show()
print(f'The r-value is {r}')
# Out:
# The r-value is 0.3391461791167537

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(southern_lat,southern_hem['Humidity'],marker="o", facecolors="violet", edgecolors ="black")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere Humidity vs. City Latitude 10/28/2020')

slope, intercept, r, p, std_err = linregress(southern_lat,southern_hem['Humidity'])
fit = slope * southern_lat + intercept
plt.plot(southern_lat,fit,color='black')
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.annotate(line_eq,(-50,20),fontsize=12,color="black")
plt.show()
print(f'The r-value is {r}')
# Out:
# The r-value is 0.16854267642077905

# %%
#The is significantly much less of a relationship betwen Humitidy and Latiditude vs. Temp
#This shows there is more at play into what effects Humidity.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(northern_lat,northern_hem['Cloudiness'],marker="o", facecolors="violet", edgecolors ="black")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere Cloudiness vs. Latitude 10/28/2020')

slope, intercept, r, p, std_err = linregress(northern_lat,northern_hem['Cloudiness'])
fit = slope * northern_lat + intercept
plt.plot(northern_lat,fit,color='black')
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.annotate(line_eq,(50,25),fontsize=12,color="black")
plt.show()
print(f'The r-value is {r}')
# Out:
# The r-value is 0.22031685356365924

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(southern_lat,southern_hem['Cloudiness'],marker="o", facecolors="violet", edgecolors ="black")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere Cloudiness vs. City Latitude 10/28/2020')

slope, intercept, r, p, std_err = linregress(southern_lat,southern_hem['Cloudiness'])
fit = slope * southern_lat + intercept
plt.plot(southern_lat,fit,color='black')
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.annotate(line_eq,(-55,25),fontsize=12,color="black")
plt.show()
print(f'The r-value is {r}')
# Out:
# The r-value is 0.14225845344302399

# %%
#Again, there is very little relationship between cloudiness and city latitude.
#This again shows outside factors at play
#Such as maybe water level?

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(northern_lat,northern_hem['Wind Speed'],marker="o", facecolors="violet", edgecolors ="black")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere Wind Speed(Mph) vs. City Latitude 10/28/2020')

slope, intercept, r, p, std_err = linregress(northern_lat,northern_hem['Wind Speed'])
fit = slope * northern_lat + intercept
plt.plot(northern_lat,fit,color='black')
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.annotate(line_eq,(30,30),fontsize=12,color="black")
plt.show()
print(f'The r-value is {r}')
# Out:
# The r-value is 0.2087362795609085

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(southern_lat,southern_hem['Wind Speed'],marker="o", facecolors="violet", edgecolors ="black")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere Wind Speed vs. City Latitude 10/28/2020')

slope, intercept, r, p, std_err = linregress(southern_lat,southern_hem['Wind Speed'])
fit = slope * southern_lat + intercept
plt.plot(southern_lat,fit,color='black')
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.annotate(line_eq,(-30,30),fontsize=12,color="black")
plt.show()
print(f'The r-value is {r}')
# Out:
# The r-value is -0.13934512985316402

# %%
#Lastly, again there is little to no relationship between windspeed and Latitude. 
#This shows with what we were given.Latitude most greatly effects Temperature over most things.
